# %%
# Solving the Problem Using darts library

# %% [markdown]
# # 0. Oil Price Prediction

# %% [markdown]
# ## Objective:
#
# Oil is a product that goes completely in a different direction for a single market event as the oil prices are rarely based on real-time data, instead, it is driven by externalities making our attempt to forecast it even more challenging As the economy will be highly affected by oil prices our model will help to understand the pattern in prices to help the customers and businesses to make smart decisions.

# %% [markdown]
# ### Sample Data Set Details:
#
# *Extraction the data from various web sources.*
#
# The following data is extracted from: [eia](https://www.eia.gov/)

# %% [markdown]
# # 1. Importing Libraries

# %%
# DARTS Library for Forecasting

#!pip install cloud-tpu-client==0.10 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.9-cp37-cp37m-linux_x86_64.whl
#!pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchtext==0.10.0 -f https://download.pytorch.org/whl/cu111/torch_stable.html

# Importing the libraries

import darts
import numpy as np
import time

from darts import TimeSeries
from darts.utils.timeseries_generation import gaussian_timeseries, linear_timeseries, sine_timeseries
from darts.models import VARIMA, StatsForecastAutoARIMA, FFT, TCNModel, TransformerModel, LightGBMModel, CatBoostModel, Prophet, RNNModel, TFTModel, DLinearModel, NLinearModel, NaiveSeasonal, NBEATSModel, ExponentialSmoothing, NHiTSModel, ARIMA
from darts.metrics import mase, mape, smape, rmse, rmsle
from darts.dataprocessing import Pipeline
from darts.dataprocessing.transformers import Scaler, StaticCovariatesTransformer, MissingValuesFiller, InvertibleMapper, InvertibleDataTransformer
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.utils.statistics import check_seasonality, plot_acf, plot_residuals_analysis, plot_hist, plot_pacf
from darts.utils.likelihood_models import QuantileRegression
from darts.utils.missing_values import fill_missing_values
from darts.models import MovingAverage


from pytorch_lightning.callbacks.early_stopping import EarlyStopping

from tqdm import tqdm

import sklearn
from sklearn import preprocessing

import pandas as pd
import torch
import matplotlib.pyplot as plt
import gc

# %matplotlib inline
torch.manual_seed(1); np.random.seed(1)  # for reproducibility
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Import Data

# %%
# Importing data-set
df_oil = pd.read_csv('oil data update.csv')
df_oil.head(10)
# Out:
#          Date  Price
# 0  02-01-1986  25.56
# 1  03-01-1986  26.00
# 2  06-01-1986  26.53
# 3  07-01-1986  25.85
# 4  08-01-1986  25.87
# 5  09-01-1986  26.03
# 6  10-01-1986  25.65
# 7  13-01-1986  25.08
# 8  14-01-1986  24.97
# 9  15-01-1986  25.18

# %% [markdown]
# # 3.Data Manipulation

# %% [markdown]
# ## 3.1. Conveting data to Time Seires

# %%
# Oil Price
# import data 
# Convert it to timeseries

oil = TimeSeries.from_dataframe(df_oil, 
                                time_col = 'Date', 
                                value_cols = ['Price'],
                                freq = 'D')

oil = oil.astype(np.float32)
oil
# Out:
# <TimeSeries (DataArray) (Date: 13501, component: 1, sample: 1)>
# array([[[11.13]],
#
#        [[13.8 ]],
#
#        [[  nan]],
#
#        ...,
#
#        [[75.19]],
#
#        [[76.09]],
#
#        [[78.29]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %% [markdown]
# ### 3.1.1. Checking seasonality of the data set.

# %%
# Adfuller test output for stationarity of the data
check_seasonality(oil, m=None, max_lag=24, alpha=0.05)
# Out:
# (False, 0)

# %% [raw]
# The data set we have is a non-stationary one so inorder to use it for model building we need to convet it to stationary one.

# %%
from matplotlib.pyplot import figure

# %%
oil.plot()

# %%
# filling Missing Values
oil_filler = MissingValuesFiller(verbose=False, n_jobs=-1, name="Filler")

# %%
# output after filling missing values
oil_filler
# Out:
# Filler

# %%
oil_scaler = Scaler(verbose=False, n_jobs=-1, name="Scaler")

# %%
oil_pipeline = Pipeline([oil_filler, oil_scaler])

# %%
oil_pipeline
# Out:
# Pipeline: Filler -> Scaler

# %%
### Transfering data to stationary one

# %%
oil_transformed = oil_pipeline.fit_transform(oil)

# %%
oil_transformed
# Out:
# <TimeSeries (DataArray) (Date: 13501, component: 1, sample: 1)>
# array([[[0.01519266]],
#
#        [[0.03478899]],
#
#        [[0.02961468]],
#
#        ...,
#
#        [[0.48535782]],
#
#        [[0.49196327]],
#
#        [[0.5081101 ]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
# Adfuller test output for stationarity of the data
check_seasonality(oil_transformed, m=None, max_lag=24, alpha=0.05)
# Out:
# (True, 23)

# %%
oil_transformed.plot()

# %%
plot_acf(oil_transformed)

# %%
plot_pacf(oil_transformed)

# %%
final_transformed = TimeSeries.pd_dataframe(oil_transformed)

# %%
final_transformed
# This is the data frame of scaled and transformed data set.
# Out:
# component      Price
# Date
# 1986-01-04  0.015193
# 1986-01-05  0.034789
# 1986-01-06  0.029615
# 1986-01-07  0.024440
# 1986-01-08  0.018349
# ...              ...
# 2022-12-17  0.480954
# 2022-12-18  0.483156
# 2022-12-19  0.485358
# 2022-12-20  0.491963
# 2022-12-21  0.508110
#
# [13501 rows x 1 columns]

# %% [markdown]
# ## 3.2. Inverse Transform of the data to see the final outputs

# %%
output = oil_pipeline.inverse_transform(oil_transformed, partial=True)

# %%
output
# Out:
# <TimeSeries (DataArray) (Date: 13501, component: 1, sample: 1)>
# array([[[11.13    ]],
#
#        [[13.8     ]],
#
#        [[13.095001]],
#
#        ...,
#
#        [[75.19    ]],
#
#        [[76.09    ]],
#
#        [[78.29    ]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
output.plot()

# %%
df_output = TimeSeries.pd_dataframe(output)

# %%
# Data frame of stationary data after post inverse transformation.
df_output
# Out:
# component       Price
# Date
# 1986-01-04  11.130000
# 1986-01-05  13.800000
# 1986-01-06  13.095001
# 1986-01-07  12.390000
# 1986-01-08  11.560000
# ...               ...
# 2022-12-17  74.590004
# 2022-12-18  74.889999
# 2022-12-19  75.190002
# 2022-12-20  76.089996
# 2022-12-21  78.290001
#
# [13501 rows x 1 columns]

# %%
# Transfering the data frame to csv file for futer use.
df_output.to_csv('post_transform.csv')

# %% [markdown]
# # 4. Moving Averages of the data

# %%
# Moving Averages for Oil Price for 7 days
oil_moving_average_7 = MovingAverage(window=7)

# %%
# Moving Averages for Oil Price for 28 days
oil_moving_average_28 = MovingAverage(window=28)

# %%
oil_moving_averages = []

# %%
ma_7 = oil_moving_average_7.filter(oil_transformed).astype(np.float32)

# %%
ma_7.head()
# Out:
# <TimeSeries (DataArray) (Date: 5, component: 1, sample: 1)>
# array([[[0.02600917]],
#
#        [[0.02447706]],
#
#        [[0.0257003 ]],
#
#        [[0.02849803]],
#
#        [[0.0328283 ]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 1986-01-08
#   * component  (component) <U20 'rolling_mean_7_Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
ma_7 = ma_7.with_columns_renamed(col_names=ma_7.components, col_names_new="oil_ma_7")

# %%
ma_7.head()
# Out:
# <TimeSeries (DataArray) (Date: 5, component: 1, sample: 1)>
# array([[[0.02600917]],
#
#        [[0.02447706]],
#
#        [[0.0257003 ]],
#
#        [[0.02849803]],
#
#        [[0.0328283 ]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 1986-01-08
#   * component  (component) object 'oil_ma_7'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
ma_28 = oil_moving_average_28.filter(oil_transformed).astype(np.float32)

# %%
ma_28.head()
# Out:
# <TimeSeries (DataArray) (Date: 5, component: 1, sample: 1)>
# array([[[0.06141546]],
#
#        [[0.06407502]],
#
#        [[0.06605045]],
#
#        [[0.06746249]],
#
#        [[0.06842405]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 1986-01-08
#   * component  (component) <U21 'rolling_mean_28_Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
ma_28 = ma_28.with_columns_renamed(col_names=ma_28.components, col_names_new="oil_ma_28")

# %%
ma_28.head()
# Out:
# <TimeSeries (DataArray) (Date: 5, component: 1, sample: 1)>
# array([[[0.06141546]],
#
#        [[0.06407502]],
#
#        [[0.06605045]],
#
#        [[0.06746249]],
#
#        [[0.06842405]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 1986-01-08
#   * component  (component) object 'oil_ma_28'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
oil_moving_averages = ma_7.stack(ma_28)

# %%
oil_moving_averages.head()
# Out:
# <TimeSeries (DataArray) (Date: 5, component: 2, sample: 1)>
# array([[[0.02600917],
#         [0.06141546]],
#
#        [[0.02447706],
#         [0.06407502]],
#
#        [[0.0257003 ],
#         [0.06605045]],
#
#        [[0.02849803],
#         [0.06746249]],
#
#        [[0.0328283 ],
#         [0.06842405]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 1986-01-08
#   * component  (component) object 'oil_ma_7' 'oil_ma_28'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %% [markdown]
# ### 4.1. Moving Average plots

# %%
plt.figure(figsize=(10, 6))
oil_transformed[-180:].plot()
oil_moving_averages[-180:].plot()
plt.title("Oil Price and Moving Averages");

# %%
output.to_csv('post_data_conversion.csv')

# %%
df_output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13501 entries, 1986-01-04 to 2022-12-21
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   13501 non-null  float32
# dtypes: float32(1)
# memory usage: 158.2 KB

# %%
# Adfuller test output for stationarity of the data
check_seasonality(output, m=None, max_lag=24, alpha=0.05)
# Out:
# (True, 23)

# %% [markdown]
# # 5. Splitting data set (for train and validation)

# %%
train, val = output.split_before(pd.Timestamp('2020-12-31'))
train.plot(label='training')
val.plot(label='validation')
plt.legend();

# %%
# Training Dataset
train
# Out:
# <TimeSeries (DataArray) (Date: 12780, component: 1, sample: 1)>
# array([[[11.13    ]],
#
#        [[13.8     ]],
#
#        [[13.095001]],
#
#        ...,
#
#        [[47.62    ]],
#
#        [[48.      ]],
#
#        [[48.4     ]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 1986-01-04 1986-01-05 ... 2020-12-30
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
# Validation Dataset
val
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample: 1)>
# array([[[ 48.52    ]],
#
#        [[ 51.035   ]],
#
#        [[ 53.55    ]],
#
#        [[ 60.64    ]],
#
#        [[ 61.45    ]],
#
#        [[ 64.585   ]],
#
#        [[ 67.72    ]],
#
#        [[ 75.23    ]],
#
#        [[ 71.91001 ]],
#
#        [[ 68.59    ]],
#
# ...
#
#        [[ 73.17    ]],
#
#        [[ 75.39    ]],
#
#        [[ 77.28    ]],
#
#        [[ 76.11    ]],
#
#        [[ 74.29    ]],
#
#        [[ 74.590004]],
#
#        [[ 74.89    ]],
#
#        [[ 75.19    ]],
#
#        [[ 76.09    ]],
#
#        [[ 78.29    ]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %% [markdown]
# # 6. Model Building

# %% [markdown]
# ## 6.1 ARIMA

# %%
# from darts.models Arima building
model1 = ARIMA()
model1.fit(train)
prediction1 = model1.predict(len(val), num_samples=100)

# %%
prediction1
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample:
#             Price_s91   Price_s92  Price_s93  Price_s94  Price_s95  Price_s96  \
# Date
# 2020-12-31  48.506504   48.506504  48.506504  48.506504  48.506504  48.506504
# 2021-01-01  49.335235   52.348617  45.336268  45.324803  47.041483  45.413076
# 2021-01-02  51.285592   54.844945  43.202486  50.252727  42.889458  47.141494
# 2021-01-03  51.427145   53.425769  38.233300  51.735396  38.990878  46.090911
# 2021-01-04  53.445508   43.769949  45.357652  52.990992  39.093659  45.951986
# ...               ...         ...        ...        ...        ...        ...
# 2022-12-17  75.400543  105.871653  27.125146  69.004635  46.278136  72.472188
# 2022-12-18  77.130131  103.759106  28.206549  72.910947  52.449357  68.760256
# 2022-12-19  78.742593  103.818870  27.710038  77.093135  54.380861  72.214083
# 2022-12-20  85.437373  102.329567  28.094510  71.563501  55.811625  73.167471
# 2022-12-21  87.477059   94.574500  32.522249  71.399437  56.047111  76.952495
#
#             Price_s97   Price_s98  Price_s99
# Date
# 2020-12-31  48.506504   48.506504  48.506504
# 2021-01-01  47.920350   45.346084  48.450216
# 2021-01-02  49.784846   45.739198  48.816920
# 2021-01-03  53.973765   42.069039  49.189285
# 2021-01-04  54.653731   37.704401  60.052651
# ...               ...         ...        ...
# 2022-12-17  -4.287884   91.618811 -27.817978
# 2022-12-18  -7.740979   96.241376 -32.558091
# 2022-12-19  -0.164390   98.705892 -34.783821
# 2022-12-20   4.321810  101.742595 -32.925309
# 2022-12-21   5.689788   98.491260 -30.064478
#
# [721 rows x 100 columns]

# %%
val.plot(label='Check')
prediction1.plot(label='Validation')
plt.legend();

# %% [markdown]
# ### 6.1.1. Model Evaluation

# %%
score_model1_mape = mape(val, prediction1)
score_model1_mape
# Out:
# 36.47105223400482

# %%
score_model1_mase = mase(val, prediction1 ,train)
score_model1_mase
# Out:
# 18.23036751736819

# %% [markdown]
# ## 6.2. Exponential Smoothing

# %%
# from darts.models import ExponentialSmoothing
model2 = ExponentialSmoothing()
model2.fit(train)
prediction2 = model2.predict(len(val), num_samples=100)

# %%
prediction2
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample: 100)>
# array([[[   55.11978634,    49.86446581,    52.09383619, ...,
#             55.20385538,    48.81160578,    49.87152541]],
#
#        [[   62.64864893,    44.78021691,    47.37685106, ...,
#             58.6523405 ,    57.22299028,    55.1305122 ]],
#
#        [[   62.36717982,    44.42028561,    52.26653386, ...,
#             61.91534697,    56.62995901,    57.4415978 ]],
#
#        ...,
#
#        [[-1826.03201298, -1058.90447125,   -65.74970951, ...,
#           -610.96196912,  1672.19056652, -1052.86355871]],
#
#        [[-1836.63157234, -1057.49575569,   -61.07920839, ...,
#           -619.71787795,  1677.1110374 , -1060.74180978]],
#
#        [[-1842.76068301, -1066.48471741,   -59.32731928, ...,
#           -621.26119718,  1682.92196966, -1066.72864157]]])
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
df_prediction2 = TimeSeries.pd_dataframe(prediction2)
df_prediction2
# Out:
# You are transforming a stochastic TimeSeries (i.e., contains several samples). The resulting DataFrame is a 2D object with all samples on the columns. If this is not the expected behavior consider calling a function adapted to stochastic TimeSeries like quantile_df
plot(label='Validation')
plt.legend();

# %% [markdown]
# ### 6.2.1. Model Evaluation

# %%
score_model2_mape = mape(val, prediction2)
score_model2_mape
# Out:
# 80.86585068878941

# %%
score_model2_mase = mase(val, prediction2, train)
score_model2_mase
# Out:
# 41.71939704230248

# %% [markdown]
# ## 6.3 StatsForecastAutoARIMA

# %%
# from darts.models Arima building
model3 = StatsForecastAutoARIMA()
model3.fit(train)
prediction3 = model3.predict(len(val), num_samples=100)

# %%
prediction3
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample: 100)>
# array([[[43.38405218, 48.66590991, 48.23077752, ..., 44.45864302,
#          45.68163438, 47.52473209]],
#
#        [[43.21332227, 44.6843814 , 49.59494932, ..., 47.49407932,
#          48.6719528 , 47.20310349]],
#
#        [[47.5664421 , 38.75524519, 45.41990517, ..., 39.55063342,
#          53.10811674, 46.64898348]],
#
#        ...,
#
#        [[29.3274104 , 47.24584814, 48.88139187, ..., 61.12618634,
#          39.70224824, 41.60210633]],
#
#        [[72.60213046, 37.23906059, 17.62468973, ..., 34.68649259,
#          34.91745577, 45.64890802]],
#
#        [[34.61641983, 15.01079892, 35.56725164, ..., 59.84513782,
#          38.83367779, 52.67525131]]])
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
df_prediction3 = TimeSeries.pd_dataframe(prediction3)
df_prediction3
# Out:
# You are transforming a stochastic TimeSeries (i.e., contains several samples). The resulting DataFrame is a 2D object with all samples on the columns. If this is not the expected behavior consider calling a function adapted to stochastic TimeSeries like quantile_df().
#              Price_s0   Price_s1   Price_s2   Price_s3   Price_s4   Price_s5  \
# Date
# 2020-12-31  43.384052  48.665910  48.230778  49.180726  41.820229  47.598662
# 2021-01-01  43.213322  44.684381  49.594949  49.324297  45.255521  52.152287
# 2021-01-02  47.566442  38.755245  45.419905  39.389341  54.668981  33.176384
# 2021-01-03  46.497176  47.557148  46.917765  43.118212  47.568572  34.087130
# 2021-01-04  47.394978  38.086451  39.252301  41.771137  50.760709  46.542740
# ...               ...        ...        ...        ...        ...        ...
# 2022-12-17  50.637704  39.070294  61.500279  24.776352  54.245561  67.524902
# 2022-12-18  60.764052  39.354272  26.748669  54.135623  57.315390  48.199289
# 2022-12-19  29.327410  47.245848  48.881392  50.326083  11.456549  52.456580
# 2022-12-20  72.602130  37.239061  17.624690  89.749269  76.299616  56.819652
# 2022-12-21  34.616420  15.010799  35.567252  52.178617  50.846066  50.014803
#
#              Price_s6   Price_s7   Price_s8   Price_s9  ...  Price_s90  \
# Date                                                    ...
# 2020-12-31  58.246728  45.919739  53.571084  49.522449  ...  47.258121
# 2021-01-01  44.548742  43.552645  43.317355  48.381865  ...  42.107322
# 2021-01-02  54.730698  48.587120  49.681079  44.416811  ...  45.578642
# 2021-01-03  48.196826  44.806659  45.374471  38.363781  ...  38.700078
# 2021-01-04  39.699126  44.069041  56.625842  39.294585  ...  48.891588
# ...               ...        ...        ...        ...  ...        ...
# 2022-12-17  31.338017   9.237288  44.650417  59.643964  ...  81.130219
# 2022-12-18  50.960559  44.493451  38.745266  19.638040  ...  45.045270
# 2022-12-19  30.111695  39.075072  77.010059  62.956939  ...  60.005463
# 2022-12-20  66.940467  66.380662  30.345696  53.019220  ...  45.703442
# ...               ...        ...        ...        ...  ...        ...
# 2022-12-17  31.338017   9.237288  44.650417  59.643964  ...  81.130219
# 2022-12-18  50.960559  44.493451  38.745266  19.638040  ...  45.045270
# 2022-12-19  30.111695  39.075072  77.010059  62.956939  ...  60.005463
# 2022-12-20  66.940467  66.380662  30.345696  53.019220  ...  45.703442
# 2022-12-21  68.821683  55.895462  26.511428  61.499396  ...  54.712506
#
#             Price_s91  Price_s92  Price_s93  Price_s94  Price_s95  Price_s96  \
# Date
# 2020-12-31  46.133264  46.695716  44.524815  50.609546  47.001359  46.585637
# 2021-01-01  41.073058  53.431043  49.334168  53.320142  49.316705  43.855539
# 2021-01-02  40.021011  56.090377  43.559044  50.135799  52.380562  49.322346
# 2021-01-03  44.947640  40.557864  45.353539  39.386299  46.840812  50.030384
# 2021-01-04  33.404949  41.205840  44.147807  40.417693  39.149605  50.802604
# ...               ...        ...        ...        ...        ...        ...
# 2022-12-17  72.939152  23.813343  27.227688  53.713359  35.377673  45.360944
# 2022-12-18  50.767188  26.397689  61.135321  32.097413  84.792801  47.453554
# 2022-12-19  54.576802  41.009025  45.403689  45.269791  63.397016  77.164342
# 2022-12-20  50.296266  43.884398  62.631746  30.042312  56.872069  50.580867
# 2022-12-21  46.382697  70.832912  31.273578  32.127655  36.934489  50.296440
#
#             Price_s97  Price_s98  Price_s99
# Date
# 2020-12-31  44.458643  45.681634  47.524732
# 2021-01-01  47.494079  48.671953  47.203103
# 2021-01-02  39.550633  53.108117  46.648983
# 2021-01-03  38.258200  53.763085  63.835304
# 2021-01-04  47.619872  51.285967  51.389544
# ...               ...        ...        ...
# 2022-12-17  64.001270  29.194095  32.516811
# 2022-12-18  54.574250  95.821230  30.162755
# 2022-12-19  61.126186  39.702248  41.602106
# 2022-12-20  34.686493  34.917456  45.648908
# 2022-12-21  59.845138  38.833678  52.675251
#
# [721 rows x 100 columns]

# %%
val.plot(label='Check')
prediction3.plot(label='Validation')
plt.legend();

# %% [markdown]
# ### 6.3.1. Model Evaluation

# %%
score_model3_mape = mape(val, prediction3)
score_model3_mape
# Out:
# 41.590052949153225

# %%
score_model3_mase = mase(val, prediction3,train)
score_model3_mase
# Out:
# 20.80369593464912

# %% [markdown]
# ## 6.4 FFT

# %%
# from darts.models Arima building
model4 = FFT()
model4.fit(train)
prediction4 = model4.predict(len(val))

# %%
prediction4
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample: 1)>
# array([[[28.68689652]],
#
#        [[28.62632569]],
#
#        [[28.56581388]],
#
#        [[28.50536174]],
#
#        [[28.44496991]],
#
#        [[28.38463904]],
#
#        [[28.32436977]],
#
#        [[28.26416276]],
#
#        [[28.20401863]],
#
#        [[28.14393804]],
#
# ...
#
#        [[14.21604147]],
#
#        [[14.22437863]],
#
#        [[14.23272821]],
#
#        [[14.24109005]],
#
#        [[14.24946399]],
#
#        [[14.25784988]],
#
#        [[14.26624758]],
#
#        [[14.27465695]],
#
#        [[14.28307784]],
#
#        [[14.2915101 ]]])
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
df_prediction4 = TimeSeries.pd_dataframe(prediction4)
df_prediction4
# Out:
# component       Price
# Date
# 2020-12-31  28.686897
# 2021-01-01  28.626326
# 2021-01-02  28.565814
# 2021-01-03  28.505362
# 2021-01-04  28.444970
# ...               ...
# 2022-12-17  14.257850
# 2022-12-18  14.266248
# 2022-12-19  14.274657
# 2022-12-20  14.283078
# 2022-12-21  14.291510
#
# [721 rows x 1 columns]

# %%
train.plot(label='Training')
prediction4.plot(label='Validation')
plt.legend();

# %%
prediction4.plot()

# %%
# Converting arima model prediction to a data frame
df_prediction4 = TimeSeries.pd_dataframe(prediction4)
df_prediction4
# Out:
# component       Price
# Date
# 2020-12-31  28.686897
# 2021-01-01  28.626326
# 2021-01-02  28.565814
# 2021-01-03  28.505362
# 2021-01-04  28.444970
# ...               ...
# 2022-12-17  14.257850
# 2022-12-18  14.266248
# 2022-12-19  14.274657
# 2022-12-20  14.283078
# 2022-12-21  14.291510
#
# [721 rows x 1 columns]

# %%
val.plot(label='Check')
prediction4.plot(label='Validation')
plt.legend();

# %% [markdown]
# ### 6.4.1. Model Evaluation

# %%
score_model4_mape = mape(val, prediction4)
score_model4_mape
# Out:
# 77.46323003708807

# %%
score_model1_mase = mase(val, prediction4 ,train)
score_model1_mase
# Out:
# 37.46800117009807

# %% [markdown]
# ## 6.5 Prophet

# %%
# from darts.models Arima building
model5 = Prophet()
model5.fit(train)
prediction5 = model5.predict(len(val))
# Out:
# 13:33:18 - cmdstanpy - INFO - Chain [1] start processing
# 13:33:54 - cmdstanpy - INFO - Chain [1] done processing

# %%
prediction5
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample: 1)>
# array([[[37.43814787]],
#
#        [[37.41836279]],
#
#        [[37.42782006]],
#
#        [[37.51139675]],
#
#        [[37.64201174]],
#
#        [[37.51661422]],
#
#        [[37.55781298]],
#
#        [[37.65921628]],
#
#        [[37.60079435]],
#
#        [[37.56667199]],
#
# ...
#
#        [[26.03252977]],
#
#        [[25.81921041]],
#
#        [[25.78406558]],
#
#        [[25.82218358]],
#
#        [[25.71473552]],
#
#        [[25.64673805]],
#
#        [[25.66468983]],
#
#        [[25.7428704 ]],
#
#        [[25.57929433]],
#
#        [[25.59731349]]])
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
df_prediction5 = TimeSeries.pd_dataframe(prediction5)
df_prediction5
# Out:
# component       Price
# Date
# 2020-12-31  37.438148
# 2021-01-01  37.418363
# 2021-01-02  37.427820
# 2021-01-03  37.511397
# 2021-01-04  37.642012
# ...               ...
# 2022-12-17  25.646738
# 2022-12-18  25.664690
# 2022-12-19  25.742870
# 2022-12-20  25.579294
# 2022-12-21  25.597313
#
# [721 rows x 1 columns]

# %%
train.plot(label='Training')
prediction5.plot(label='Validation')
plt.legend();

# %%
prediction5.plot()

# %%
# Converting arima model prediction to a data frame
df_prediction5 = TimeSeries.pd_dataframe(prediction5)
df_prediction5
# Out:
# component       Price
# Date
# 2020-12-31  37.438148
# 2021-01-01  37.418363
# 2021-01-02  37.427820
# 2021-01-03  37.511397
# 2021-01-04  37.642012
# ...               ...
# 2022-12-17  25.646738
# 2022-12-18  25.664690
# 2022-12-19  25.742870
# 2022-12-20  25.579294
# 2022-12-21  25.597313
#
# [721 rows x 1 columns]

# %%
val.plot(label='Check')
prediction5.plot(label='Validation')
plt.legend();

# %% [markdown]
# ### 6.5.1. Model Evaluation

# %%
score_model5_mape = mape(val, prediction5)
score_model5_mape
# Out:
# 57.14686994186423

# %%
score_model5_mase = mase(val, prediction5 ,train)
score_model5_mase
# Out:
# 28.13417024304185

# %% [markdown]
# # Neural Network Based Models

# %% [markdown]
# ## 6.6 RNNModel (Vanila RNN)

# %%
# acf plot of training data
plot_acf(train)

# %%
# pacf plot of training data
plot_pacf(train)

# %% [raw]
# So based on the pack graph we konw 24 days data has impact on the prediction so for the RNN model better
# to go with 24 days data as chunk length.

# %%
# from darts.models Arima building
model6 = RNNModel(input_chunk_length= 15 , # Input window size
    output_chunk_length=1, # Output window size
    hidden_dim=25, # Number of neurons in the hidden layer
    n_rnn_layers=3, # Number of layers in the RNN
    dropout=0.5, # Dropout rate
    batch_size=16, # Number of input-output pairs in each training batch
    n_epochs=50, # Number of training epochs
    # optimizer_kwargs={'lr': 1e-3} # Optimizer parameters
)
model6.fit(train)
prediction6 = model6.predict(len(val))
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | rnn           | RNN              | 3.3 K
# 4 | V             | Linear           | 26
# ---------------------------------------------------
# 3.3 K     Trainable params
# 0         Non-trainable params
# 3.3 K     Total params
# 0.013     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
prediction6
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample: 1)>
# array([[[46.600845]],
#
#        [[43.86077 ]],
#
#        [[41.703163]],
#
#        [[40.807224]],
#
#        [[40.658207]],
#
#        [[40.769108]],
#
#        [[40.838085]],
#
#        [[40.779316]],
#
#        [[40.72457 ]],
#
#        [[40.7275  ]],
#
# ...
#
#        [[40.745365]],
#
#        [[40.745365]],
#
#        [[40.745365]],
#
#        [[40.745365]],
#
#        [[40.745365]],
#
#        [[40.745365]],
#
#        [[40.745365]],
#
#        [[40.745365]],
#
#        [[40.745365]],
#
#        [[40.745365]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
df_prediction6 = TimeSeries.pd_dataframe(prediction6)
df_prediction6
# Out:
# component       Price
# Date
# 2020-12-31  46.600845
# 2021-01-01  43.860771
# 2021-01-02  41.703163
# 2021-01-03  40.807224
# 2021-01-04  40.658207
# ...               ...
# 2022-12-17  40.745365
# 2022-12-18  40.745365
# 2022-12-19  40.745365
# 2022-12-20  40.745365
# 2022-12-21  40.745365
#
# [721 rows x 1 columns]

# %%
train.plot(label='Training')
prediction6.plot(label='Validation')
plt.legend();

# %%
prediction6.plot()

# %%
# Converting arima model prediction to a data frame
df_prediction6 = TimeSeries.pd_dataframe(prediction6)
df_prediction6
# Out:
# component       Price
# Date
# 2020-12-31  46.600845
# 2021-01-01  43.860771
# 2021-01-02  41.703163
# 2021-01-03  40.807224
# 2021-01-04  40.658207
# ...               ...
# 2022-12-17  40.745365
# 2022-12-18  40.745365
# 2022-12-19  40.745365
# 2022-12-20  40.745365
# 2022-12-21  40.745365
#
# [721 rows x 1 columns]

# %%
val.plot(label='Check')
prediction6.plot(label='Validation')
plt.legend();

# %% [markdown]
# ### 6.6.1. Model Evaluation

# %%
score_model6_mape = mape(val, prediction6)
score_model6_mape
# Out:
# 47.459033131599426

# %%
score_model6_mase = mase(val, prediction6 ,train)
score_model6_mase
# Out:
# 23.470787

# %% [markdown]
# ## 6.7 RNN Model (LSTM: Long Short Temporary Model)

# %%
# from darts.models Arima building
model7 = RNNModel(model='LSTM',
    hidden_dim=25,
    dropout=0.5,
    batch_size=16,
    n_epochs=50,
    input_chunk_length= 15 , # Input window size
    output_chunk_length=1, # Output window size
    n_rnn_layers=3
)

# %%
model7.fit(train)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | rnn           | LSTM             | 13.2 K
# 4 | V             | Linear           | 26
# ---------------------------------------------------
# 13.2 K    Trainable params
# 0         Non-trainable params
# 13.2 K    Total params
# 0.053     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=50` reached.

# %%
prediction7 = model7.predict(len(val), num_samples=1)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
prediction7
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample: 1)>
# array([[[49.904152]],
#
#        [[51.553986]],
#
#        [[53.250355]],
#
#        [[54.96297 ]],
#
#        [[56.451485]],
#
#        [[57.47305 ]],
#
#        [[57.994144]],
#
#        [[58.205875]],
#
#        [[58.295876]],
#
#        [[58.365623]],
#
# ...
#
#        [[70.10964 ]],
#
#        [[70.10964 ]],
#
#        [[70.10964 ]],
#
#        [[70.10964 ]],
#
#        [[70.10965 ]],
#
#        [[70.10966 ]],
#
#        [[70.10966 ]],
#
#        [[70.10966 ]],
#
#        [[70.109665]],
#
#        [[70.109665]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
df_prediction7 = TimeSeries.pd_dataframe(prediction7)
df_prediction7
# Out:
# component       Price
# Date
# 2020-12-31  49.904152
# 2021-01-01  51.553986
# 2021-01-02  53.250355
# 2021-01-03  54.962971
# 2021-01-04  56.451485
# ...               ...
# 2022-12-17  70.109657
# 2022-12-18  70.109657
# 2022-12-19  70.109657
# 2022-12-20  70.109665
# 2022-12-21  70.109665
#
# [721 rows x 1 columns]

# %%
train.plot(label='Training')
prediction7.plot(label='Validation')
plt.legend();

# %%
prediction7.plot()

# %%
# Converting arima model prediction to a data frame
df_prediction7 = TimeSeries.pd_dataframe(prediction7)
df_prediction7
# Out:
# component       Price
# Date
# 2020-12-31  49.904152
# 2021-01-01  51.553986
# 2021-01-02  53.250355
# 2021-01-03  54.962971
# 2021-01-04  56.451485
# ...               ...
# 2022-12-17  70.109657
# 2022-12-18  70.109657
# 2022-12-19  70.109657
# 2022-12-20  70.109665
# 2022-12-21  70.109665
#
# [721 rows x 1 columns]

# %%
val.plot(label='Check')
prediction7.plot(label='Validation')
plt.legend();

# %% [markdown]
# ### 6.7.1. Model Evaluation

# %%
score_model7_mape = mape(val, prediction7)
score_model7_mape
# Out:
# 16.90472960472107

# %%
score_model7_mase = mase(val, prediction7 ,train)
score_model7_mase
# Out:
# 8.833303

# %% [markdown]
# ## 6.8 RNN Model (GRU)

# %%
# from darts.models Arima building
model8 = RNNModel(model='GRU',
    hidden_dim=25,
    dropout=0.5,
    batch_size=16,
    n_epochs=50,
    input_chunk_length= 15 , # Input window size
    output_chunk_length=1, # Output window size
    n_rnn_layers=3
)

# %%
model8.fit(train)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | rnn           | GRU              | 9.9 K
# 4 | V             | Linear           | 26
# ---------------------------------------------------
# 9.9 K     Trainable params
# 0         Non-trainable params
# 9.9 K     Total params
# 0.040     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=50` reached.

# %%
prediction8 = model8.predict(len(val), num_samples=1)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
prediction8
# Out:
# <TimeSeries (DataArray) (Date: 721, component: 1, sample: 1)>
# array([[[48.801006 ]],
#
#        [[49.040276 ]],
#
#        [[49.18644  ]],
#
#        [[49.285706 ]],
#
#        [[49.369324 ]],
#
#        [[49.452393 ]],
#
#        [[49.524727 ]],
#
#        [[49.59325  ]],
#
#        [[49.649696 ]],
#
#        [[49.700394 ]],
#
# ...
#
#        [[ 3.098907 ]],
#
#        [[ 3.0933032]],
#
#        [[ 3.0877223]],
#
#        [[ 3.0821662]],
#
#        [[ 3.0766273]],
#
#        [[ 3.071113 ]],
#
#        [[ 3.0656219]],
#
#        [[ 3.0601497]],
#
#        [[ 3.0547004]],
#
#        [[ 3.0492702]]], dtype=float32)
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 ... 2022-12-21
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
df_prediction8 = TimeSeries.pd_dataframe(prediction8)
df_prediction8
# Out:
# component       Price
# Date
# 2020-12-31  48.801006
# 2021-01-01  49.040276
# 2021-01-02  49.186440
# 2021-01-03  49.285706
# 2021-01-04  49.369324
# ...               ...
# 2022-12-17   3.071113
# 2022-12-18   3.065622
# 2022-12-19   3.060150
# 2022-12-20   3.054700
# 2022-12-21   3.049270
#
# [721 rows x 1 columns]

# %%
train.plot(label='Training')
prediction8.plot(label='Validation')
plt.legend();

# %%
prediction8.plot(label='Prediction')
# val.plot(label='valisation set')

# %%
val.plot(label='Check')
prediction8.plot(label='Validation')
plt.legend();

# %% [markdown]
# ### 6.8.1. Model Evaluation

# %%
score_model8_mape = mape(val, prediction8)
score_model8_mape
# Out:
# 68.9201831817627

# %%
score_model8_mase = mase(val, prediction8 ,train)
score_model8_mase
# Out:
# 34.943146

# %% [markdown]
# # Serializing and dumping Model

# %%
import pickle as pkl

# Dump the model to disk using pickle
filename = 'model6.pkl'
with open(filename, 'wb') as file:
    pkl.dump(model6, file)

# %%
# Dump the model to disk using pickle
filename = 'model7.pkl'
with open(filename, 'wb') as file:
    pkl.dump(model7, file)

# %%
# Dump the model to disk using pickle
filename = 'model1.pkl'
with open(filename, 'wb') as file:
    pkl.dump(model1, file)

# %%
# Dump the model to disk using pickle
filename = 'model2.pkl'
with open(filename, 'wb') as file:
    pkl.dump(model2, file)

# %%
# Dump the model to disk using pickle
filename = 'model3.pkl'
with open(filename, 'wb') as file:
    pkl.dump(model3, file)

# %%
# Dump the model to disk using pickle
#filename = 'model4.pkl'
#with open(filename, 'wb') as file:
    #pkl.dump(model4, file)

# %%
# Dump the model to disk using pickle
filename = 'model5.pkl'
with open(filename, 'wb') as file:
    pkl.dump(model5, file)

# %%
# Dump the model to disk using pickle
filename = 'model8.pkl'
with open(filename, 'wb') as file:
    pkl.dump(model8, file)

# %% [markdown]
# # Deployment Pickle

# %%
#import pickle
#pickle_out = open("bag.pkl","wb")
#pickle.dump(bag, pickle_out)
#pickle_out.close()

# %%
from pickle import dump
dump([model1,model2,model3,model5,model6,model7,model8],
open('allmodels_1.sav','wb'))

# %%
import dill as pickle
from pickle import dump
dump([model1,model2,model3,model4,model5,model6,model7,model8],
open('allmodels_1.sav','wb'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[142], line 3
#       1 import dill as pickle
#       2 from pickle import dump
# ----> 3 dump([model1,model2,model3,model4,model5,model6,model7,model8],
#       4 open('allmodels_1.sav','wb'))
#
# AttributeError: Can't pickle local object 'FFT.fit.<locals>.<lambda>'

# %%
from pickle import dump
dump([model1,model2,model3,model4,model5,model6,model7,model8],
open('allmodels_1.sav','wb'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[140], line 2
#       1 from pickle import dump
# ----> 2 dump([model1,model2,model3,model4,model5,model6,model7,model8],
#       3 open('allmodels_1.sav','wb'))
#
# AttributeError: Can't pickle local object 'FFT.fit.<locals>.<lambda>'

# %%
# Old project code
#  from pickle import dump
# dump([logisticlassifier,MNB,KNN_classifier,model_linear,dt,bag,RFC],
# open('allmodels_1.sav','wb'))

# %%
import pickle

# %%
from pickle import dump
# Load the saved model from disk
with open('model5.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
loaded_model.predict(3)
# Out:
# <TimeSeries (DataArray) (Date: 3, component: 1, sample: 1)>
# array([[[37.43814787]],
#
#        [[37.41836279]],
#
#        [[37.42782006]]])
# Coordinates:
#   * Date       (Date) datetime64[ns] 2020-12-31 2021-01-01 2021-01-02
#   * component  (component) object 'Price'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None
